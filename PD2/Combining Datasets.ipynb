# %%
import pandas as pd

# %%
df1 = pd.read_csv('udacity.csv')
df2 = pd.read_csv('coursera.csv')
df3 = pd.read_csv('udemy.csv')

# %%
df1.rename(columns={'img_src': 'course_img'}, inplace=True)
df1['paid'] = 'Yes'
df1['students_count']='N/A'
df1.head()
# Out:
#                        title        Type  \
# 0  Data Engineering with AWS  nanodegree
# 1            Product Manager  nanodegree
# 2                        C++  nanodegree
# 3         Business Analytics  nanodegree
# 4             Data Scientist  nanodegree
#
#                                          description         level  \
# 0  Learn to design data models, build data wareho...  intermediate
# 1  Envision and execute the development of indust...      beginner
# 2  Get hands-on experience building five real-wor...  intermediate
# 3  Gain foundational data skills like analyzing d...      beginner
# 4  Build effective machine learning models, run d...      advanced
#
#   course_duration  ratings  reviews_count  \
# 0        4 Months      4.6         1802.0
# 1        4 Months      4.7          864.0
# 2        4 Months      4.5         1126.0
# 3        3 Months      4.8         2649.0
# 4        4 Months      4.7         1212.0
#
# ...

# %%
df2['paid'] = 'Yes'
df2.head()
# Out:
#                                                title  \
# 0  (ISC)² Systems Security Certified Practitioner...
# 1                           .NET FullStack Developer
# 2  21st Century Energy Transition: how do we make...
# 3  A Crash Course in Causality:  Inferring Causal...
# 4                                           AI & Law
#
#                  organization course_certificate_type course_duration  \
# 0                        ISC2          Specialization    3 - 6 Months
# 1              Board Infinity          Specialization    1 - 3 Months
# 2       University of Alberta                  Course    1 - 3 Months
# 3  University of Pennsylvania                  Course    1 - 3 Months
# 4             Lund University                  Course     1 - 4 Weeks
#
#    ratings reviews_count         level  \
# 0      4.7           484      Beginner
# 1      4.3            49  Intermediate
# 2      4.8            59      Beginner
# 3      4.7           515  Intermediate
# ...

# %%
df3['paid'] = 'Yes'
df3.head()
# Out:
#                                                title  \
# 0  2022 Complete Python Bootcamp From Zero to Her...
# 1                    The Web Developer Bootcamp 2022
# 2         The Complete 2022 Web Development Bootcamp
# 3        Angular - The Complete Guide (2023 Edition)
# 4  Java Programming Masterclass covering Java 11 ...
#
#                                           instructor  \
# 0                                      Jose Portilla
# 1                                        Colt Steele
# 2                                      Dr. Angela Yu
# 3                           Maximilian Schwarzmüller
# 4  Tim Buchalka, Tim Buchalka's Learn Programming...
#
#                                           course_url  \
# 0  https://www.udemy.com/course/complete-python-b...
# 1  https://www.udemy.com/course/the-web-developer...
# 2  https://www.udemy.com/course/the-complete-web-...
# 3  https://www.udemy.com/course/the-complete-guid...
# ...

# %%
df1.to_csv('udacity.csv', index=False)
df2.to_csv('coursera.csv', index=False)
df3.to_csv('udemy.csv', index=False)

# %%
df1.head()
# Out:
#                        title        Type  \
# 0  Data Engineering with AWS  nanodegree
# 1            Product Manager  nanodegree
# 2                        C++  nanodegree
# 3         Business Analytics  nanodegree
# 4             Data Scientist  nanodegree
#
#                                          description         level  \
# 0  Learn to design data models, build data wareho...  intermediate
# 1  Envision and execute the development of indust...      beginner
# 2  Get hands-on experience building five real-wor...  intermediate
# 3  Gain foundational data skills like analyzing d...      beginner
# 4  Build effective machine learning models, run d...      advanced
#
#   course_duration  ratings  reviews_count  \
# 0        4 Months      4.6         1802.0
# 1        4 Months      4.7          864.0
# 2        4 Months      4.5         1126.0
# 3        3 Months      4.8         2649.0
# 4        4 Months      4.7         1212.0
#
# ...

# %%
df2.head()
# Out:
#                                                title  \
# 0  (ISC)² Systems Security Certified Practitioner...
# 1                           .NET FullStack Developer
# 2  21st Century Energy Transition: how do we make...
# 3  A Crash Course in Causality:  Inferring Causal...
# 4                                           AI & Law
#
#                  organization course_certificate_type course_duration  \
# 0                        ISC2          Specialization    3 - 6 Months
# 1              Board Infinity          Specialization    1 - 3 Months
# 2       University of Alberta                  Course    1 - 3 Months
# 3  University of Pennsylvania                  Course    1 - 3 Months
# 4             Lund University                  Course     1 - 4 Weeks
#
#    ratings reviews_count         level  \
# 0      4.7           484      Beginner
# 1      4.3            49  Intermediate
# 2      4.8            59      Beginner
# 3      4.7           515  Intermediate
# ...

# %%
df3.head()
# Out:
#                                                title  \
# 0  2022 Complete Python Bootcamp From Zero to Her...
# 1                    The Web Developer Bootcamp 2022
# 2         The Complete 2022 Web Development Bootcamp
# 3        Angular - The Complete Guide (2023 Edition)
# 4  Java Programming Masterclass covering Java 11 ...
#
#                                           instructor  \
# 0                                      Jose Portilla
# 1                                        Colt Steele
# 2                                      Dr. Angela Yu
# 3                           Maximilian Schwarzmüller
# 4  Tim Buchalka, Tim Buchalka's Learn Programming...
#
#                                           course_url  \
# 0  https://www.udemy.com/course/complete-python-b...
# 1  https://www.udemy.com/course/the-web-developer...
# 2  https://www.udemy.com/course/the-complete-web-...
# 3  https://www.udemy.com/course/the-complete-guid...
# ...
