# %%
import pandas as pd

# %%
df1 = pd.read_csv("coursera.csv")
df2 = pd.read_csv('udacity.csv')
df3 =  pd.read_csv('udemy.csv')

# %%
col1
# Out:
#                                                  title  \
# 0    (ISC)² Systems Security Certified Practitioner...
# 1                             .NET FullStack Developer
# 2    21st Century Energy Transition: how do we make...
# 3    A Crash Course in Causality:  Inferring Causal...
# 4                                             AI & Law
# ..                                                 ...
# 931  Using Python to Interact with the Operating Sy...
# 932                             Value Chain Management
# 933                                   Value-Based Care
# 934                                    Version Control
# 935  Viral Marketing and How to Craft Contagious Co...
#
#                                    organization course_certificate_type  \
# 0                                          ISC2          Specialization
# 1                                Board Infinity          Specialization
# 2                         University of Alberta                  Course
# ...

# %%
backup1 = df1
backup2 = df2
backup3 = df3

# %%
newdf1 = pd.concat([df1,df2,df3],ignore_index=True)

# %%
newdf1
# Out:
#                                                   title organization  \
# 0     (ISC)² Systems Security Certified Practitioner...          N/A
# 1                              .NET FullStack Developer          N/A
# 2     21st Century Energy Transition: how do we make...          N/A
# 3     A Crash Course in Causality:  Inferring Causal...          N/A
# 4                                              AI & Law          N/A
# ...                                                 ...          ...
# 6209  Game Theory Algorithms in Competitive Programm...          NaN
# 6210  Siemens WinCC SCADA Programming, SCADA1 ( Basic )          NaN
# 6211  Python Object Oriented Programming (OOP): Begi...          NaN
# 6212                                jQuery Basics Guide          NaN
# 6213  Introduction to Android Development for beginners          NaN
#
#      course_certificate_type  course_duration               ratings  \
# 0                        N/A     3 - 6 Months                   4.7
# ...

# %%
newdf1.shape
# Out:
# (6214, 20)

# %%
newdf1.isnull().sum().sum()
# Out:
# 41167

# %%
newdf1.fillna("N/A", inplace=True)

# %%
newdf1.isnull().sum()
# Out:
# title                      0
# organization               0
# course_certificate_type    0
# course_duration            0
# ratings                    0
# reviews_count              0
# level                      0
# course_url                 0
# students_count             0
# course_skills              0
# course_summary             0
# description                0
# platform                   0
# course_img                 0
# paid                       0
# Type                       0
# Prerequisites              0
# domain                     0
# instructor                 0
# lectures_count             0
# dtype: int64

# %%
newdf1.to_csv("combined_data.csv", index=False)
